# %%
# %matplotlib inline
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key
from datetime import datetime
import time

# %%
#Generate a new set of 1,500 random latitudes and longitudes.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#print coordinates from the zip lat/long file
coordinates = list(lat_lngs)
print(coordinates[:20])
# Out:
# [(-65.61143616428899, -94.1424571330586), (-73.88789908061058, 141.87231299618804), (60.864041818937636, -2.5991398588560912), (36.968469262651354, -179.66589361954325), (37.772132848275916, -69.21801256830523), (-7.767187734493618, -93.54046799030296), (70.09989141324024, 116.267972432026), (11.391018941529083, -77.6221966180803), (-8.565070761870516, -38.341166764979675), (49.51663325690262, -133.1993678029716), (-66.2932848137414, 103.82429606881317), (89.2069511660402, -169.54409282415918), (-3.445649617954331, -89.25205504510937), (50.37581086044332, -161.156396494549), (-58.65295524933754, -139.21864468810475), (51.77479852353733, -140.14627244929383), (71.60564999128968, -166.28058419966663), (19.400470908489325, 54.09363162401539), (41.64237514195028, -20.056138211841414), (-53.467248433064334, -174.96122515607686)]

# %%
# Get the nearest city using 
city_list = list()

for j in coordinates:
    city_name = citipy.nearest_city(j[0], j[1]).city_name
    if city_name not in city_list:
        city_list.append(city_name)
print(city_list[:10],len(city_list))
# Out:
# ['punta arenas', 'hobart', 'brae', 'kapaa', 'nantucket', 'puerto ayora', 'saskylakh', 'tigre', 'floresta', 'prince rupert'] 622

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8a8f3743cd9de275d97a88345ed6688

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval-----")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
 # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#if it is raining, get the amount of rainfall in inches for the last three hours. If it is not raining, add 0 inches for the city   
        try:
            
            city_rain = city_weather['rain']['3h']
        
        except:
            city_rain = 0
            
# if it is snowing, get the amount of snow in inches for the last three hours. If it is not snowing, add 0 inches for the city.
        try:
            
            city_snow = city_weather['snow']['3h']
        
        except:
            city_snow = 0

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Rain inches(last 3hrs)": city_rain,
                          "Snow inches(last 3hrs)": city_snow,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval-----
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | brae
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | nantucket
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | tigre
# Processing Record 9 of Set 1 | floresta
# Processing Record 10 of Set 1 | prince rupert
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | san cristobal
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | nome
# Processing Record 18 of Set 1 | salalah
# Processing Record 19 of Set 1 | vila franca do campo
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | chuy
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
cityWeatherdatadf = pd.DataFrame(city_data)
cityWeatherdatadf.head(10)
# Out:
#             City Country                 Date    Lat     Lng  Max Temp  \
# 0   Punta Arenas      CL  2020-01-06 03:06:30 -53.16  -70.91     46.40
# 1         Hobart      AU  2020-01-06 03:04:03 -42.88  147.33     77.00
# 2           Brae      GB  2020-01-06 03:06:30  60.40   -1.35     50.00
# 3          Kapaa      US  2020-01-06 03:02:49  22.08 -159.32     80.60
# 4      Nantucket      US  2020-01-06 03:06:30  41.28  -70.10     35.60
# 5   Puerto Ayora      EC  2020-01-06 03:02:42  -0.74  -90.35     75.99
# 6      Saskylakh      RU  2020-01-06 03:06:30  71.97  114.09    -16.62
# 7          Tigre      AR  2020-01-06 03:06:30 -34.42  -58.58     77.00
# 8       Floresta      BR  2020-01-06 03:06:30  -8.60  -38.57     79.90
# 9  Prince Rupert      CA  2020-01-06 03:03:48  54.32 -130.32     37.40
#
#    Humidity  Cloudiness  Wind Speed  Rain inches(last 3hrs)  \
# 0        61          40       12.75                    0.00
# 1        55          20       17.22                    0.00
# ...

# %%
newColumnOrder = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain inches(last 3hrs)", "Snow inches(last 3hrs)"]
cityWeatherdatadf = cityWeatherdatadf[newColumnOrder]

# %%
cityWeatherdatadf
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0    Punta Arenas      CL  2020-01-06 03:06:30 -53.16  -70.91     46.40
# 1          Hobart      AU  2020-01-06 03:04:03 -42.88  147.33     77.00
# 2            Brae      GB  2020-01-06 03:06:30  60.40   -1.35     50.00
# 3           Kapaa      US  2020-01-06 03:02:49  22.08 -159.32     80.60
# 4       Nantucket      US  2020-01-06 03:06:30  41.28  -70.10     35.60
# ..            ...     ...                  ...    ...     ...       ...
# 545      Alegrete      BR  2020-01-06 03:07:19 -29.79  -55.79     76.62
# 546       Batagay      RU  2020-01-06 03:07:19  67.65  134.64    -20.81
# 547    Coahuayana      MX  2020-01-06 03:07:19  18.62 -100.35     72.73
# 548     Dongsheng      CN  2020-01-06 03:07:19  29.72  112.52     45.14
# 549       Dapitan      PH  2020-01-06 03:07:19  10.27  123.95     84.20
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
# Create the output file (CSV).
output_data_file = "Data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
cityWeatherdatadf.to_csv(output_data_file, index_label="City_ID")

# %%
cityWeatherdatadf.head()
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0  Punta Arenas      CL  2020-01-06 03:06:30 -53.16  -70.91      46.4
# 1        Hobart      AU  2020-01-06 03:04:03 -42.88  147.33      77.0
# 2          Brae      GB  2020-01-06 03:06:30  60.40   -1.35      50.0
# 3         Kapaa      US  2020-01-06 03:02:49  22.08 -159.32      80.6
# 4     Nantucket      US  2020-01-06 03:06:30  41.28  -70.10      35.6
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        61          40       12.75    scattered clouds
# 1        55          20       17.22          few clouds
# 2        87         100       17.22          light rain
# 3        74          75       19.46       broken clouds
# 4        55           1       11.41           clear sky
#
#    Rain inches(last 3hrs)  Snow inches(last 3hrs)
# 0                    0.00                     0.0
# 1                    0.00                     0.0
# 2                    0.44                     0.0
# ...

# %%
type(cityWeatherdatadf)
# Out:
# pandas.core.frame.DataFrame

# %%
# How many cities have recorded rainfall in the dataframe?
rainfall = len(cityWeatherdatadf[cityWeatherdatadf["Rain inches(last 3hrs)"]>0])
rainfall
# Out:
# 55

# %%
#How many cities have recorded snowfall in the dataframe?
snowfall = len(cityWeatherdatadf[cityWeatherdatadf["Snow inches(last 3hrs)"]>0])
snowfall
# Out:
# 26
